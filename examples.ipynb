# %%
# %matplotlib nbagg

# %%
import jefimenko
# Out:
# Jefimenko version 0.0.1

# %%
def example_charges_1():
    mapping = jefimenko.Grid(1,   # creat a 1D grid
                delta=[1],  # this is the size of a step in x, y and z
                size=[10],  # this is the size of the grid in meters
                time=14 * 3.36 * 10**-9,  # this is the length of a simulation in secounds
                delta_t=3.36 * 10**-9  # this is the size of a full time step
        )
 
    mapping.Add_Charge([0], Q = 1)
    jefimenko.plot_grid(mapping)

    jefimenko.simulate(mapping)
    for t in range(mapping.time_size):
        #t=1
        jefimenko.plot_EM_grid('E', mapping, time=t)

    for T in range(10):
        print(T)
        field = jefimenko.print_location(mapping.grid['E'][T], [1, 0], mapping)
        print(field)

# %%
example_charges_1()
# Out:
# location = [0]Q = 1
# <img src="data:image/png;base64,..." width="640">
# shape = 1
# simulating grid
# grid simulated
# <img src="data:image/png;base64,..." width="640">
# The acutal time is 0.0
# <img src="data:image/png;base64,..." width="640">
# The acutal time is 3.36e-09
# <img src="data:image/png;base64,..." width="640">
# The acutal time is 6.72e-09
# <img src="data:image/png;base64,..." width="640">
# The acutal time is 1.008e-08
# <img src="data:image/png;base64,..." width="640">
# The acutal time is 1.344e-08
# <img src="data:image/png;base64,..." width="640">
# The acutal time is 1.6799999999999998e-08
# <img src="data:image/png;base64,..." width="640">
# The acutal time is 2.016e-08
# <img src="data:image/png;base64,..." width="640">
# The acutal time is 2.352e-08
# <img src="data:image/png;base64,..." width="640">
# The acutal time is 2.688e-08
# <img src="data:image/png;base64,..." width="640">
# The acutal time is 3.024e-08
# <img src="data:image/png;base64,..." width="640">
# The acutal time is 3.3599999999999996e-08
# <img src="data:image/png;base64,..." width="640">
# The acutal time is 3.696e-08
# <img src="data:image/png;base64,..." width="640">
# The acutal time is 4.032e-08
# <img src="data:image/png;base64,..." width="640">
# The acutal time is 4.368e-08
# 0
#  the field is = 0j
#  the vector is = (nan+nanj)
#  the nomalized field is = 0.0
# (0j, (nan+nanj), 0.0)
# 1
#  the field is = (8987551787.368176+0j)
#  the vector is = (1+0j)
#  the nomalized field is = 8987551787.368176
# ((8987551787.368176+0j), (1+0j), 8987551787.368176)
# 2
#  the field is = (8987551787.368176+0j)
#  the vector is = (1+0j)
#  the nomalized field is = 8987551787.368176
# ((8987551787.368176+0j), (1+0j), 8987551787.368176)
# 3
#  the field is = (8987551787.368176+0j)
#  the vector is = (1+0j)
#  the nomalized field is = 8987551787.368176
# ((8987551787.368176+0j), (1+0j), 8987551787.368176)
# 4
#  the field is = (8987551787.368176+0j)
#  the vector is = (1+0j)
#  the nomalized field is = 8987551787.368176
# ((8987551787.368176+0j), (1+0j), 8987551787.368176)
# 5
#  the field is = (8987551787.368176+0j)
#  the vector is = (1+0j)
#  the nomalized field is = 8987551787.368176
# ((8987551787.368176+0j), (1+0j), 8987551787.368176)
# 6
#  the field is = (8987551787.368176+0j)
#  the vector is = (1+0j)
#  the nomalized field is = 8987551787.368176
# ((8987551787.368176+0j), (1+0j), 8987551787.368176)
# 7
#  the field is = (8987551787.368176+0j)
#  the vector is = (1+0j)
#  the nomalized field is = 8987551787.368176
# ((8987551787.368176+0j), (1+0j), 8987551787.368176)
# 8
#  the field is = (8987551787.368176+0j)
#  the vector is = (1+0j)
#  the nomalized field is = 8987551787.368176
# ((8987551787.368176+0j), (1+0j), 8987551787.368176)
# 9
#  the field is = (8987551787.368176+0j)
#  the vector is = (1+0j)
#  the nomalized field is = 8987551787.368176
# ((8987551787.368176+0j), (1+0j), 8987551787.368176)
# /home/nehemiah/programing/jefimenko/git/non-constant_terms/Jefimenko/jefimenko/graphing.py:347: RuntimeWarning: invalid value encountered in cdouble_scalars
#   vector = field[tuple(index)] / np.linalg.norm(field[tuple(index)])

# %%
def example_charges_2():
    mapping = jefimenko.Grid(2,   # creat a 2D grid
                delta=[1, 1],  # this is the size of a step in x, y and z
                size=[10, 10],  # this is the size of the grid in meters
                time=14 * 3.36 * 10**-9,  # this is the length of a simulation in secounds
                delta_t=3.36 * 10**-9  # this is the size of a full time step
        )
 
    mapping.Add_Charge([0, 0], Q = 1)
    jefimenko.plot_grid(mapping)

    jefimenko.simulate(mapping)
    for t in range(mapping.time_size):
        #t=1
        jefimenko.plot_EM_grid('E', mapping, time=t)

    for T in range(10):
        print(T)
        field = jefimenko.print_location(mapping.grid['E'][T], [1, 0], mapping)
        print(field)

# %%
example_charges_2()

# %%
def example_charges_3():
    mapping = jefimenko.Grid(3,   # creat a 3D grid
                delta=[1, 1, 1],  # this is the size of a step in x, y and z
                size=[10, 10, 10],  # this is the size of the grid in meters
                time=14 * 3.36 * 10**-9,  # this is the length of a simulation in secounds
                delta_t=3.36 * 10**-9  # this is the size of a full time step
        )
 
    mapping.Add_Charge([0, 0, 0], Q = 1)
    jefimenko.plot_grid(mapping)

    jefimenko.simulate(mapping)
    for t in range(mapping.time_size):
        #t=1
        jefimenko.plot_EM_grid('E', mapping, time=t)

#    for T in range(10):
#        print(T)
#        field = jefimenko.print_location(mapping.grid['E'][T], [1, 0], mapping)
#        print(field)

# %%
example_charges_3()

# %%
def example_currents():
    mapping = jefimenko.Grid(2,   # creat a 2D grid
                delta=[1, 1],  # this is the size of a step in x, y and z
                size=[10, 10],  # this is the size of the grid in meters
                time=14 * 3.36 * 10**-9,  # this is the length of a simulation in secounds
                delta_t=3.36 * 10**-9  # this is the size of a full time step
        )
    for i in range(10):
        mapping.Add_Current([5, i],
                        direction=[0, 1, 0],
                        Amps=1)
    jefimenko.plot_grid(mapping)

    for i in range(len(mapping.currents[0])):
        print('amps = ' + str(mapping.currents[0][i].amps))
        print('direction = ' + str(mapping.currents[0][i].direction))
        print('location = '+ str(mapping.currents[0][i].location))
        print('')
    jefimenko.simulate(mapping)
    for t in range(mapping.time_size):
         #t=1
        jefimenko.plot_EM_grid('H', mapping, time=t)

    for T in range(10):
        print(T)
        field = jefimenko.print_location(mapping.grid['H'][T], [1, 0], mapping)
        print(field)

# %%
example_currents()

# %%
def example_currents_1():
    mapping = jefimenko.Grid(1,   # creat a 1D grid
                delta=[1],  # this is the size of a step in x, y and z
                size=[10],  # this is the size of the grid in meters
                time=14 * 3.36 * 10**-9,  # this is the length of a simulation in secounds
                delta_t=3.36 * 10**-9  # this is the size of a full time step
        )
    mapping.Add_Current([0],
                    direction=[0, 0, 1],
                    Amps=1)

    jefimenko.plot_grid(mapping)

    for i in range(len(mapping.currents[0])):
        print('amps = ' + str(mapping.currents[0][i].amps))
        print('direction = ' + str(mapping.currents[0][i].direction))
        print('location = '+ str(mapping.currents[0][i].location))
        print('')
    jefimenko.simulate(mapping)
    for t in range(mapping.time_size):
         #t=1
        jefimenko.plot_EM_grid('H', mapping, time=t)

    for T in range(10):
        print(T)
        field = jefimenko.print_location(mapping.grid['H'][T], [1], mapping)
        print(field)

# %%
example_currents_1()

# %%
def example_currents_2():
    mapping = jefimenko.Grid(2,   # creat a 2D grid
                delta=[1, 1],  # this is the size of a step in x, y and z
                size=[10, 10],  # this is the size of the grid in meters
                time=14 * 3.36 * 10**-9,  # this is the length of a simulation in secounds
                delta_t=3.36 * 10**-9  # this is the size of a full time step
        )
    mapping.Add_Current([5, 5],
                    direction=[0, 0, 1],
                    Amps=1)

    jefimenko.plot_grid(mapping)

    for i in range(len(mapping.currents[0])):
        print('amps = ' + str(mapping.currents[0][i].amps))
        print('direction = ' + str(mapping.currents[0][i].direction))
        print('location = '+ str(mapping.currents[0][i].location))
        print('')
    jefimenko.simulate(mapping)
    for t in range(mapping.time_size):
         #t=1
        jefimenko.plot_EM_grid('H', mapping, time=t)

    for T in range(10):
        print(T)
        field = jefimenko.print_location(mapping.grid['H'][T], [1, 0], mapping)
        print(field)

# %%
example_currents_2()

# %%
def example_currents_3():
    mapping = jefimenko.Grid(3,   # creat a 3D grid
                delta=[1, 1, 1],  # this is the size of a step in x, y and z
                size=[10, 10, 3],  # this is the size of the grid in meters
                time=14 * 3.36 * 10**-9,  # this is the length of a simulation in secounds
                delta_t=3.36 * 10**-9  # this is the size of a full time step
        )
    for i in range(3):
        mapping.Add_Current([5, 5, i],
                            direction=[0, 0, 1],
                            Amps=1)

    jefimenko.plot_grid(mapping)

    for i in range(len(mapping.currents[0])):
        print('amps = ' + str(mapping.currents[0][i].amps))
        print('direction = ' + str(mapping.currents[0][i].direction))
        print('location = '+ str(mapping.currents[0][i].location))
        print('')
    jefimenko.simulate(mapping)
    for t in range(mapping.time_size):
        jefimenko.plot_EM_grid('H', mapping, time=t)

    for T in range(10):
        print(T)
        field = jefimenko.print_location(mapping.grid['H'][T], [1, 0, 0], mapping)
        print(field)

# %%
example_currents_3()
